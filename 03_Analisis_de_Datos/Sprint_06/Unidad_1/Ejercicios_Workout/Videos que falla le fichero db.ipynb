# %%
import pandas as pd
import sqlite3

# %%
conection = sqlite3.connect("C:/Users/Usuario/desktop/repos/DS_Online_Feb24_Exercises/03_Analisis_de_Datos/Sprint_06/Unidad_1/Practica_Obligatoria/data/chinook.db")

# %%
cursor_clase = conection.cursor()

# %%
res = cursor_clase.execute("SELECT name FROM sqlite_master WHERE type = 'table'")
tablas = []
for name in res:
    print(name[0])
    tablas.append(name[0])
print(tablas)
# Out:
# albums
# sqlite_sequence
# artists
# customers
# employees
# genres
# invoices
# invoice_items
# media_types
# playlists
# playlist_track
# tracks
# sqlite_stat1
# films
# ['albums', 'sqlite_sequence', 'artists', 'customers', 'employees', 'genres', 'invoices', 'invoice_items', 'media_types', 'playlists', 'playlist_track', 'tracks', 'sqlite_stat1', 'films']

# %%
query = "SELECT * FROM employees"
cursor_clase.execute(query)

# %%
cursor_clase.fetchone()
# Out:
# (1,
#  'Adams',
#  'Andrew',
#  'General Manager',
#  None,
#  '1962-02-18 00:00:00',
#  '2002-08-14 00:00:00',
#  '11120 Jasper Ave NW',
#  'Edmonton',
#  'AB',
#  'Canada',
#  'T5K 2N1',
#  '+1 (780) 428-9482',
#  '+1 (780) 428-3457',
#  'andrew@chinookcorp.com')

# %%
cursor_clase.fetchmany()
# Out:
# [(2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com')]

# %%
cursor_clase.fetchmany(20)
# Out:
# [(3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5G3',
#   '+1 (403) 263-4423',
#   '+1 (403) 263-4289',
#   'margaret@chinookcorp.com'),
#  (5,
#   'Johnson',
#   'Steve',
#   'Sales Support Agent',
#   2,
#   '1965-03-03 00:00:00',
#   '2003-10-17 00:00:00',
#   '7727B 41 Ave',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T3B 1Y7',
#   '1 (780) 836-9987',
#   '1 (780) 836-9543',
#   'steve@chinookcorp.com'),
#  (6,
#   'Mitchell',
#   'Michael',
#   'IT Manager',
#   1,
#   '1973-07-01 00:00:00',
#   '2003-10-17 00:00:00',
#   '5827 Bowness Road NW',
#   'Calgary',
# ...

# %%
cursor_clase.fetchall()
# Out:
# []

# %%
query = "SELECT * FROM employees"
cursor_clase.execute(query)

# %%
cursor_clase.fetchall()
# Out:
# [(1,
#   'Adams',
#   'Andrew',
#   'General Manager',
#   None,
#   '1962-02-18 00:00:00',
#   '2002-08-14 00:00:00',
#   '11120 Jasper Ave NW',
#   'Edmonton',
#   'AB',
#   'Canada',
#   'T5K 2N1',
#   '+1 (780) 428-9482',
#   '+1 (780) 428-3457',
#   'andrew@chinookcorp.com'),
#  (2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com'),
#  (3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
# ...

# %%
cursor_clase.description
# Out:
# (('EmployeeId', None, None, None, None, None, None),
#  ('LastName', None, None, None, None, None, None),
#  ('FirstName', None, None, None, None, None, None),
#  ('Title', None, None, None, None, None, None),
#  ('ReportsTo', None, None, None, None, None, None),
#  ('BirthDate', None, None, None, None, None, None),
#  ('HireDate', None, None, None, None, None, None),
#  ('Address', None, None, None, None, None, None),
#  ('City', None, None, None, None, None, None),
#  ('State', None, None, None, None, None, None),
#  ('Country', None, None, None, None, None, None),
#  ('PostalCode', None, None, None, None, None, None),
#  ('Phone', None, None, None, None, None, None),
#  ('Fax', None, None, None, None, None, None),
#  ('Email', None, None, None, None, None, None))

# %%
names_col = []
names_col = [name[0] for name in cursor_clase.description]names_col = [name[0] for name in cursor_clase.description]
names_col
# Out:
# ['EmployeeId',
#  'LastName',
#  'FirstName',
#  'Title',
#  'ReportsTo',
#  'BirthDate',
#  'HireDate',
#  'Address',
#  'City',
#  'State',
#  'Country',
#  'PostalCode',
#  'Phone',
#  'Fax',
#  'Email']

# %%
cursor_clase.execute(query)
resultado = cursor_clase.fetchall()
df = pd.DataFrame(resultado, columns=names_col)
df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
def sql_df (query):
    cursor_clase.execute(query)
    names_col = [name[0] for name in cursor_clase.description]
    resultado = cursor_clase.fetchall()
    return pd.DataFrame(resultado, columns=names_col)

# %%
query = '''
SELECT *
FROM employees
'''
df = sql_df(query)
df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
query = '''
SELECT *
FROM tracks
'''
df = sql_df(query)
dfquery = '''
SELECT *
FROM tracks
'''
df = sql_df(query)
df
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
query = '''
SELECT DISTINCT Composer AS Autor, Name
FROM tracks
'''
df = sql_df(query)
df
# Out:
#                                                   Autor  \
# 0             Angus Young, Malcolm Young, Brian Johnson
# 1                                                  None
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...
# 3     F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 4                            Deaffy & R.A. Smith-Diesel
# ...                                                 ...
# 3418                                               None
# 3419                                     Franz Schubert
# 3420                                 Claudio Monteverdi
# 3421                            Wolfgang Amadeus Mozart
# 3422                                       Philip Glass
#
#                                                    Name
# 0               For Those About To Rock (We Salute You)
# 1                                     Balls to the Wall
# 2                                       Fast As a Shark
# 3                                     Restless and Wild
# ...
